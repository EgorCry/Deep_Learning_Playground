# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('DS_Sber.csv', sep=';')
data.columns = data.columns.str.lower()
data['reportdate'] = data['reportdate'].str.replace('.', '/')
data["reportdate"] = pd.to_datetime(data["reportdate"], infer_datetime_format=True)

data[250:].head(10)
# Out:
# C:\Temp\ipykernel_4524\1512527829.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['reportdate'] = data['reportdate'].str.replace('.', '/')
#     reportdate        value
# 250 2014-09-06   5860195697
# 251 2014-09-07   5860195697
# 252 2014-09-08  19175854331
# 253 2014-09-09  19739611315
# 254 2014-09-10  19433070371
# 255 2014-09-11  21240088060
# 256 2014-09-12  21297842724
# 257 2014-09-13  21297842724
# 258 2014-09-14  21297842724
# 259 2014-09-15  19514183323

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   reportdate  2111 non-null   datetime64[ns]
#  1   value       2111 non-null   int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 33.1 KB

# %%
data.describe()
# Out:
#               value
# count  2.111000e+03
# mean   3.389668e+10
# std    1.875474e+10
# min    3.282810e+09
# 25%    1.824160e+10
# 50%    3.021352e+10
# 75%    4.758339e+10
# max    7.822860e+10

# %%
data.boxplot(['value'])
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot: >

# %%
plt.figure(figsize=(10, 7))

plt.grid(True)
plt.plot(data.reportdate, data.value)

plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential, load_model
from keras.layers import LSTM, Dense, Dropout

# %%
df = data['value'].values.reshape((-1, 1))[252:]
df
# Out:
# array([[19175854331],
#        [19739611315],
#        [19433070371],
#        ...,
#        [68424049766],
#        [72492897583],
#        [72307860851]], dtype=int64)

# %%
dataset_train = np.array(df[:int(df.shape[0]*0.8)])
dataset_test = np.array(df[int(df.shape[0]*0.8):])

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
dataset_train = scaler.fit_transform(dataset_train)
dataset_test = scaler.transform(dataset_test)

dataset_train
# Out:
# array([[0.12949958],
#        [0.14128199],
#        [0.13487535],
#        ...,
#        [0.75412709],
#        [0.76059506],
#        [0.77529796]])

# %%
def create_dataset(df, window):
    x = []
    y = []
    for i in range(window, df.shape[0]):
        x.append(df[i-window:i, 0])
        y.append(df[i, 0])
    x = np.array(x)
    y = np.array(y)
    return (x, y)

# %%
window = 30

x_train, y_train = create_dataset(dataset_train, window)
x_test, y_test = create_dataset(dataset_test, window)

x_train, y_train
# Out:
# (array([[0.12949958, 0.14128199, 0.13487535, ..., 0.1191465 , 0.10843478,
#          0.12159391],
#         [0.14128199, 0.13487535, 0.17264166, ..., 0.10843478, 0.12159391,
#          0.12816072],
#         [0.13487535, 0.17264166, 0.17384872, ..., 0.12159391, 0.12816072,
#          0.13530325],
#         ...,
#         [0.7304616 , 0.7304616 , 0.72986828, ..., 0.74705403, 0.74705403,
#          0.74705403],
#         [0.7304616 , 0.72986828, 0.70238989, ..., 0.74705403, 0.74705403,
#          0.75412709],
#         [0.72986828, 0.70238989, 0.7172788 , ..., 0.74705403, 0.75412709,
#          0.76059506]]),
#  array([0.12816072, 0.13530325, 0.15456172, ..., 0.75412709, 0.76059506,
#         0.77529796]))

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

x_train.shape, y_train.shape
# Out:
# ((1457, 30, 1), (1457,))

# %%
def create_model():
    model = Sequential(name='Sber')
    model.add(LSTM(units=128, activation='relu', return_sequences=True, input_shape=(x_train.shape[1], 1)))
    model.add(Dropout(0.2))
    model.add(LSTM(units=128, return_sequences=True, activation='relu'))
    model.add(Dropout(0.2))
    model.add(LSTM(units=1, activation='relu'))
    model.add(Dense(units=1))
    
    model.compile(loss='mean_squared_error', optimizer='adam')
    
    return model

# %%
model = create_model()

model.summary()
# Out:
# Model: "Sber"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 128)           66560
#
#  dropout (Dropout)           (None, 30, 128)           0
#
#  lstm_1 (LSTM)               (None, 30, 128)           131584
#
#  dropout_1 (Dropout)         (None, 30, 128)           0
#
#  lstm_2 (LSTM)               (None, 1)                 520
#
#  dense (Dense)               (None, 1)                 2
#
# =================================================================
# Total params: 198,666
# Trainable params: 198,666
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, batch_size=16, epochs=50)
# Out:
# Epoch 1/50
# 183/183 [==============================] - 8s 27ms/step - loss: 0.0153
# Epoch 2/50
# 183/183 [==============================] - 5s 28ms/step - loss: 0.0046
# Epoch 3/50
# 183/183 [==============================] - 5s 27ms/step - loss: 0.0049
# Epoch 4/50
# 183/183 [==============================] - 5s 28ms/step - loss: 0.0037
# Epoch 5/50
# 183/183 [==============================] - 5s 28ms/step - loss: 0.0027
# Epoch 6/50
# 183/183 [==============================] - 6s 32ms/step - loss: 0.0029
# Epoch 7/50
# 183/183 [==============================] - 6s 33ms/step - loss: 0.0024
# Epoch 8/50
# 183/183 [==============================] - 5s 27ms/step - loss: 0.0021
# Epoch 9/50
# 183/183 [==============================] - 5s 28ms/step - loss: 0.0021
# Epoch 10/50
# 183/183 [==============================] - 5s 27ms/step - loss: 0.0021
# Epoch 11/50
# 183/183 [==============================] - 5s 26ms/step - loss: 0.0019
# Epoch 12/50
# 183/183 [==============================] - 5s 28ms/step - loss: 0.0018
# Epoch 13/50
# 183/183 [==============================] - 5s 27ms/step - loss: 0.0018
# Epoch 14/50
# 183/183 [==============================] - 5s 28ms/step - loss: 0.0017
# Epoch 15/50
# 183/183 [==============================] - 5s 27ms/step - loss: 0.0016
# Epoch 16/50
# 183/183 [==============================] - 5s 25ms/step - loss: 0.0018
# Epoch 17/50
# 183/183 [==============================] - 5s 30ms/step - loss: 0.0014
# Epoch 18/50
# 183/183 [==============================] - 5s 27ms/step - loss: 0.0015
# Epoch 19/50
# 183/183 [==============================] - 5s 25ms/step - loss: 0.0015
# Epoch 20/50
# 183/183 [==============================] - 5s 25ms/step - loss: 0.0014
# Epoch 21/50
# 183/183 [==============================] - 5s 25ms/step - loss: 0.0019
# Epoch 22/50
# 183/183 [==============================] - 5s 25ms/step - loss: 0.0014
# Epoch 23/50
# 183/183 [==============================] - 5s 25ms/step - loss: 0.0013
# Epoch 24/50
# 183/183 [==============================] - 5s 25ms/step - loss: 0.0014
# Epoch 25/50
# 183/183 [==============================] - 5s 26ms/step - loss: 0.0014
# Epoch 26/50
# 183/183 [==============================] - 5s 25ms/step - loss: 0.0015
# Epoch 27/50
# 183/183 [==============================] - 5s 25ms/step - loss: 0.0011
# Epoch 28/50
# 183/183 [==============================] - 5s 25ms/step - loss: 0.0011
# Epoch 29/50
# 183/183 [==============================] - 5s 25ms/step - loss: 0.0012
# Epoch 30/50
# 183/183 [==============================] - 5s 25ms/step - loss: 0.0013
# Epoch 31/50
# 183/183 [==============================] - 5s 25ms/step - loss: 0.0012
# Epoch 32/50
# 183/183 [==============================] - 5s 25ms/step - loss: 0.0011
# Epoch 33/50
# 183/183 [==============================] - 5s 25ms/step - loss: 0.0011
# Epoch 34/50
# 183/183 [==============================] - 5s 25ms/step - loss: 9.9885e-04
# Epoch 35/50
# 183/183 [==============================] - 5s 25ms/step - loss: 0.0011
# Epoch 36/50
# 183/183 [==============================] - 5s 25ms/step - loss: 9.7458e-04
# Epoch 37/50
# 183/183 [==============================] - 5s 25ms/step - loss: 0.0011
# Epoch 38/50
# 183/183 [==============================] - 5s 26ms/step - loss: 0.0011
# Epoch 39/50
# 183/183 [==============================] - 5s 25ms/step - loss: 0.0010
# Epoch 40/50
# 183/183 [==============================] - 5s 25ms/step - loss: 0.0010
# Epoch 41/50
# 183/183 [==============================] - 5s 25ms/step - loss: 0.0010
# Epoch 42/50
# 183/183 [==============================] - 5s 25ms/step - loss: 9.9044e-04
# Epoch 43/50
# 183/183 [==============================] - 5s 26ms/step - loss: 8.6219e-04
# Epoch 44/50
# 183/183 [==============================] - 5s 25ms/step - loss: 0.0011
# Epoch 45/50
# 183/183 [==============================] - 5s 25ms/step - loss: 0.0011
# Epoch 46/50
# 183/183 [==============================] - 5s 25ms/step - loss: 0.0011
# Epoch 47/50
# 183/183 [==============================] - 5s 25ms/step - loss: 9.9062e-04
# Epoch 48/50
# 183/183 [==============================] - 5s 25ms/step - loss: 9.7439e-04
# Epoch 49/50
# 183/183 [==============================] - 5s 25ms/step - loss: 0.0011
# Epoch 50/50
# 183/183 [==============================] - 5s 25ms/step - loss: 9.2853e-04

# %%
predict = model.predict(x_test)
predict = scaler.inverse_transform(predict)
y_test_scaled = scaler.inverse_transform(y_test.reshape(-1, 1))

plt.figure(figsize=(16, 8))

plt.plot(y_test_scaled, color='r', label='Original')
plt.plot(predict, color='b', label='Predicted')

plt.legend()

plt.show()

# %%
dataset_valid = np.array(df)

dataset_valid = scaler.transform(dataset_valid)

dataset_valid = np.reshape(dataset_valid, (dataset_valid.shape[0], dataset_valid.shape[1], 1))

x_dataset_valid, y_dataset_valid = create_dataset(dataset_valid, window)

predict = model.predict(x_dataset_valid)
predict = scaler.inverse_transform(predict)
dataset_valid = scaler.inverse_transform(y_dataset_valid)

plt.figure(figsize=(16, 8))

plt.plot(dataset_valid, color='r', label='Original')
plt.plot(predict, color='b', label='Predicted')

plt.legend()

plt.show()

# %%
df_1 = df.copy()

for i in range(window):
    test = df_1.copy()

    test = test[-window:]

    test = scaler.transform(test.reshape(-1, 1)).reshape(-1)

    test = scaler.inverse_transform(model.predict(test.reshape(1, window, 1))).reshape(-1)

    df_1 = np.append(df_1, test)
    
df_1[-window:]
# Out:
# array([6.19477729e+10, 5.96967588e+10, 5.83331840e+10, 5.70595000e+10,
#        5.58669251e+10, 5.49247345e+10, 5.42782341e+10, 5.37562644e+10,
#        5.33503590e+10, 5.30268283e+10, 5.27155978e+10, 5.23162173e+10,
#        5.19550730e+10, 5.17558682e+10, 5.16956979e+10, 5.16983890e+10,
#        5.17032468e+10, 5.17342372e+10, 5.18421996e+10, 5.20272896e+10,
#        5.22291937e+10, 5.24598886e+10, 5.26411735e+10, 5.28433603e+10,
#        5.31365274e+10, 5.36636047e+10, 5.42438605e+10, 5.44094659e+10,
#        5.42014259e+10, 5.35530291e+10])

# %%
plt.plot(df_1)

# %%
test = df.copy()

test = test[-window:]

test = scaler.transform(test.reshape(-1, 1)).reshape(-1)

test = scaler.inverse_transform(model.predict(test.reshape(1, window, 1))).reshape(-1)

test.reshape(-1)
# Out:
# array([6.1947773e+10], dtype=float32)

# %%
plt.plot(df)

plt.plot(np.append(np.array(df)*0, test.reshape(-1)))

# %%
def create_model_1():
    model = Sequential(name='Sber')
    model.add(LSTM(units=128, activation='relu', return_sequences=True, input_shape=(x_test_1.shape[1], 1)))
    model.add(Dropout(0.2))
    model.add(LSTM(units=128, return_sequences=True, activation='relu'))
    model.add(Dropout(0.2))
    model.add(LSTM(units=1, activation='relu'))
    model.add(Dense(units=1))
    
    model.compile(loss='mean_squared_error', optimizer='adam')
    
    return model

# %%
scaler_1 = MinMaxScaler(feature_range=(0, 1))
# dataset_test_1 = scaler_1.fit_transform(np.array(df[int(df.shape[0]*0.8):]))
dataset_test_1 = scaler_1.fit_transform(np.array(df))

x_test_1, y_test_1 = create_dataset(dataset_test_1, window)

x_test_1 = np.reshape(x_test_1, (x_test_1.shape[0], x_test_1.shape[1], 1))

model_1 = create_model_1()

model_1.summary()
# Out:
# Model: "Sber"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_15 (LSTM)              (None, 30, 128)           66560
#
#  dropout_10 (Dropout)        (None, 30, 128)           0
#
#  lstm_16 (LSTM)              (None, 30, 128)           131584
#
#  dropout_11 (Dropout)        (None, 30, 128)           0
#
#  lstm_17 (LSTM)              (None, 1)                 520
#
#  dense_5 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 198,666
# Trainable params: 198,666
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_1.fit(x_test_1, y_test_1, batch_size=16, epochs=50)
# Out:
# Epoch 1/50
# 115/115 [==============================] - 6s 30ms/step - loss: 0.0166
# Epoch 2/50
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0040
# Epoch 3/50
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0035
# Epoch 4/50
# 115/115 [==============================] - 4s 32ms/step - loss: 0.0032
# Epoch 5/50
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0029
# Epoch 6/50
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0022
# Epoch 7/50
# 115/115 [==============================] - 3s 29ms/step - loss: 0.0021
# Epoch 8/50
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0019
# Epoch 9/50
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0016
# Epoch 10/50
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0015
# Epoch 11/50
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0015
# Epoch 12/50
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0014
# Epoch 13/50
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0014
# Epoch 14/50
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0013
# Epoch 15/50
# 115/115 [==============================] - 4s 32ms/step - loss: 0.0013
# Epoch 16/50
# 115/115 [==============================] - 4s 31ms/step - loss: 0.0013
# Epoch 17/50
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0011
# Epoch 18/50
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0014
# Epoch 19/50
# 115/115 [==============================] - 4s 32ms/step - loss: 0.0012
# Epoch 20/50
# 115/115 [==============================] - 4s 36ms/step - loss: 0.0013
# Epoch 21/50
# 115/115 [==============================] - 5s 41ms/step - loss: 0.0011
# Epoch 22/50
# 115/115 [==============================] - 4s 39ms/step - loss: 0.0012
# Epoch 23/50
# 115/115 [==============================] - 4s 37ms/step - loss: 0.0011
# Epoch 24/50
# 115/115 [==============================] - 4s 32ms/step - loss: 0.0011
# Epoch 25/50
# 115/115 [==============================] - 4s 34ms/step - loss: 0.0011
# Epoch 26/50
# 115/115 [==============================] - 4s 31ms/step - loss: 0.0010
# Epoch 27/50
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0010
# Epoch 28/50
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0011
# Epoch 29/50
# 115/115 [==============================] - 4s 33ms/step - loss: 0.0011
# Epoch 30/50
# 115/115 [==============================] - 3s 30ms/step - loss: 0.0010
# Epoch 31/50
# 115/115 [==============================] - 4s 33ms/step - loss: 0.0011
# Epoch 32/50
# 115/115 [==============================] - 5s 39ms/step - loss: 0.0010
# Epoch 33/50
# 115/115 [==============================] - 4s 33ms/step - loss: 8.8216e-04
# Epoch 34/50
# 115/115 [==============================] - 4s 32ms/step - loss: 9.8574e-04
# Epoch 35/50
# 115/115 [==============================] - 4s 32ms/step - loss: 0.0011
# Epoch 36/50
# 115/115 [==============================] - 4s 33ms/step - loss: 9.2221e-04
# Epoch 37/50
# 115/115 [==============================] - 4s 32ms/step - loss: 8.1489e-04
# Epoch 38/50
# 115/115 [==============================] - 4s 32ms/step - loss: 8.6120e-04
# Epoch 39/50
# 115/115 [==============================] - 4s 32ms/step - loss: 8.1239e-04
# Epoch 40/50
# 115/115 [==============================] - 4s 33ms/step - loss: 8.1558e-04
# Epoch 41/50
# 115/115 [==============================] - 4s 32ms/step - loss: 8.7218e-04
# Epoch 42/50
# 115/115 [==============================] - 4s 32ms/step - loss: 8.1599e-04
# Epoch 43/50
# 115/115 [==============================] - 4s 35ms/step - loss: 9.4901e-04
# Epoch 44/50
# 115/115 [==============================] - 3s 30ms/step - loss: 8.2852e-04
# Epoch 45/50
# 115/115 [==============================] - 4s 32ms/step - loss: 7.7434e-04
# Epoch 46/50
# 115/115 [==============================] - 4s 31ms/step - loss: 7.4986e-04
# Epoch 47/50
# 115/115 [==============================] - 3s 30ms/step - loss: 8.3409e-04
# Epoch 48/50
# 115/115 [==============================] - 4s 31ms/step - loss: 7.3465e-04
# Epoch 49/50
# 115/115 [==============================] - 4s 33ms/step - loss: 8.1761e-04
# Epoch 50/50
# 115/115 [==============================] - 4s 31ms/step - loss: 8.1295e-04

# %%
plt.plot(y_test_1)
plt.plot(model_1.predict(x_test_1))

# %%
model_1.predict(x_test_1)
# Out:
# array([[0.08331494],
#        [0.08563174],
#        [0.08874112],
#        ...,
#        [0.85041106],
#        [0.87075615],
#        [0.8927305 ]], dtype=float32)

# %%
test_1 = scaler.transform(df.reshape(-1, 1))

test_1 = test_1[-window:]

test_1 = test_1.reshape(1, window, 1)

model_1.predict(test_1), test_1
# Out:
# (array([[0.55568635]], dtype=float32),
#  array([[[1.30557636],
#          [1.27752816],
#          [1.252851  ],
#          [1.252851  ],
#          [1.252851  ],
#          [1.13842297],
#          [1.09438731],
#          [1.08230591],
#          [1.08281573],
#          [1.04964708],
#          [1.04964708],
#          [1.04964708],
#          [1.03843219],
#          [0.99529029],
#          [0.95776782],
#          [0.99219015],
#          [1.00452333],
#          [1.00452333],
#          [1.00452333],
#          [1.01024898],
#          [1.01607316],
#          [1.05777508],
#          [1.05041245],
#          [1.07948504],
#          [1.07948504],
#          [1.07948504],
#          [1.11052433],
#          [1.15877698],
#          [1.24381508],
#          [1.23994785]]]))
