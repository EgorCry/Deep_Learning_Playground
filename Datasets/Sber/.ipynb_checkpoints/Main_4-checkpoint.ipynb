# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('DS_Sber.csv', sep=';')
data.columns = data.columns.str.lower()
data['reportdate'] = data['reportdate'].str.replace('.', '/')
data["reportdate"] = pd.to_datetime(data["reportdate"], infer_datetime_format=True)

data.head(10)
# Out:
# C:\Temp\ipykernel_9768\4256145899.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['reportdate'] = data['reportdate'].str.replace('.', '/')
#   reportdate       value
# 0 2013-12-30  3457625638
# 1 2013-12-31  3417092149
# 2 2014-01-01  3417092149
# 3 2014-01-02  3417092149
# 4 2014-01-03  3417092149
# 5 2014-01-04  3417092149
# 6 2014-01-05  3417092149
# 7 2014-01-06  3320846785
# 8 2014-01-07  3320846785
# 9 2014-01-08  3630283744

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   reportdate  2111 non-null   datetime64[ns]
#  1   value       2111 non-null   int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 33.1 KB

# %%
data.describe()
# Out:
#               value
# count  2.111000e+03
# mean   3.389668e+10
# std    1.875474e+10
# min    3.282810e+09
# 25%    1.824160e+10
# 50%    3.021352e+10
# 75%    4.758339e+10
# max    7.822860e+10

# %%
data.boxplot(['value'])
# Out:
# <AxesSubplot: >

# %%
plt.figure(figsize=(10, 7))

plt.grid(True)
plt.plot(data.reportdate, data.value)

plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential, load_model
from keras.layers import LSTM, Dense, Dropout

# %%
df = data['value'].values.reshape((-1, 1))
df
# Out:
# array([[ 3457625638],
#        [ 3417092149],
#        [ 3417092149],
#        ...,
#        [68424049766],
#        [72492897583],
#        [72307860851]], dtype=int64)

# %%
dataset_train = np.array(df[:int(df.shape[0]*0.8)])
dataset_test = np.array(df[int(df.shape[0]*0.8):])

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
dataset_train = scaler.fit_transform(dataset_train)
dataset_test = scaler.transform(dataset_test)

dataset_train
# Out:
# array([[0.00303794],
#        [0.00233355],
#        [0.00233355],
#        ...,
#        [0.9404834 ],
#        [0.9404834 ],
#        [0.95731266]])

# %%
def create_dataset(df, window):
    x = []
    y = []
    for i in range(window, df.shape[0]):
        x.append(df[i-window:i, 0])
        y.append(df[i, 0])
    x = np.array(x)
    y = np.array(y)
    return (x, y)

# %%
window = 360

x_train, y_train = create_dataset(dataset_train, window)
x_test, y_test = create_dataset(dataset_test, window)

x_train, y_train
# Out:
# (array([[0.00303794, 0.00233355, 0.00233355, ..., 0.19360971, 0.1965626 ,
#          0.20017247],
#         [0.00233355, 0.00233355, 0.00233355, ..., 0.1965626 , 0.20017247,
#          0.19961109],
#         [0.00233355, 0.00233355, 0.00233355, ..., 0.20017247, 0.19961109,
#          0.20768011],
#         ...,
#         [0.69606591, 0.68815967, 0.66941469, ..., 0.93544849, 0.96823825,
#          0.9404834 ],
#         [0.68815967, 0.66941469, 0.66941469, ..., 0.96823825, 0.9404834 ,
#          0.9404834 ],
#         [0.66941469, 0.66941469, 0.66941469, ..., 0.9404834 , 0.9404834 ,
#          0.9404834 ]]),
#  array([0.19961109, 0.20768011, 0.20768011, ..., 0.9404834 , 0.9404834 ,
#         0.95731266]))

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

x_train
# Out:
# array([[[0.00303794],
#         [0.00233355],
#         [0.00233355],
#         ...,
#         [0.19360971],
#         [0.1965626 ],
#         [0.20017247]],
#
#        [[0.00233355],
#         [0.00233355],
#         [0.00233355],
#         ...,
#         [0.1965626 ],
#         [0.20017247],
#         [0.19961109]],
#
#        [[0.00233355],
#         [0.00233355],
#         [0.00233355],
#         ...,
#         [0.20017247],
#         [0.19961109],
#         [0.20768011]],
#
#        ...,
#
#        [[0.69606591],
#         [0.68815967],
#         [0.66941469],
#         ...,
#         [0.93544849],
#         [0.96823825],
#         [0.9404834 ]],
#
#        [[0.68815967],
#         [0.66941469],
#         [0.66941469],
#         ...,
#         [0.96823825],
#         [0.9404834 ],
#         [0.9404834 ]],
#
#        [[0.66941469],
#         [0.66941469],
#         [0.66941469],
#         ...,
#         [0.9404834 ],
#         [0.9404834 ],
#         [0.9404834 ]]])

# %%
def create_model():
    model = Sequential(name='Sber')
    model.add(LSTM(units=128, return_sequences=True, input_shape=(x_train.shape[1], 1)))
    model.add(Dropout(0.2))
    model.add(LSTM(units=64, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(units=64))
    model.add(Dense(units=1))
    
    model.compile(loss='mean_squared_error', optimizer='adam')
    
    return model

# %%
model = create_model()

model.fit(x_train, y_train, batch_size=16, epochs=50)
# Out:
# Epoch 1/50
# 83/83 [==============================] - 30s 301ms/step - loss: 0.0153
# Epoch 2/50
# 83/83 [==============================] - 25s 296ms/step - loss: 0.0034
# Epoch 3/50
# 83/83 [==============================] - 27s 328ms/step - loss: 0.0027
# Epoch 4/50
# 83/83 [==============================] - 25s 301ms/step - loss: 0.0029
# Epoch 5/50
# 83/83 [==============================] - 25s 300ms/step - loss: 0.0025
# Epoch 6/50
# 83/83 [==============================] - 25s 307ms/step - loss: 0.0023
# Epoch 7/50
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0016
# Epoch 8/50
# 83/83 [==============================] - 25s 303ms/step - loss: 0.0014
# Epoch 9/50
# 83/83 [==============================] - 25s 296ms/step - loss: 0.0013
# Epoch 10/50
# 83/83 [==============================] - 25s 298ms/step - loss: 0.0013
# Epoch 11/50
# 83/83 [==============================] - 25s 296ms/step - loss: 0.0013
# Epoch 12/50
# 83/83 [==============================] - 24s 294ms/step - loss: 0.0012
# Epoch 13/50
# 83/83 [==============================] - 26s 317ms/step - loss: 0.0011
# Epoch 14/50
# 83/83 [==============================] - 25s 301ms/step - loss: 0.0012
# Epoch 15/50
# 83/83 [==============================] - 24s 295ms/step - loss: 0.0012
# Epoch 16/50
# 83/83 [==============================] - 24s 293ms/step - loss: 0.0011
# Epoch 17/50
# 83/83 [==============================] - 24s 295ms/step - loss: 9.4223e-04
# Epoch 18/50
# 83/83 [==============================] - 25s 296ms/step - loss: 9.5381e-04
# Epoch 19/50
# 83/83 [==============================] - 24s 293ms/step - loss: 9.5183e-04
# Epoch 20/50
# 83/83 [==============================] - 25s 295ms/step - loss: 8.9146e-04
# Epoch 21/50
# 83/83 [==============================] - 24s 292ms/step - loss: 8.4682e-04
# Epoch 22/50
# 83/83 [==============================] - 24s 292ms/step - loss: 8.3137e-04
# Epoch 23/50
# 83/83 [==============================] - 24s 291ms/step - loss: 7.7518e-04
# Epoch 24/50
# 83/83 [==============================] - 24s 292ms/step - loss: 0.0011
# Epoch 25/50
# 83/83 [==============================] - 24s 292ms/step - loss: 8.2730e-04
# Epoch 26/50
# 83/83 [==============================] - 24s 289ms/step - loss: 8.1283e-04
# Epoch 27/50
# 83/83 [==============================] - 24s 290ms/step - loss: 7.4510e-04
# Epoch 28/50
# 83/83 [==============================] - 24s 288ms/step - loss: 8.9637e-04
# Epoch 29/50
# 83/83 [==============================] - 24s 288ms/step - loss: 8.4649e-04
# Epoch 30/50
# 83/83 [==============================] - 24s 288ms/step - loss: 7.0404e-04
# Epoch 31/50
# 83/83 [==============================] - 24s 288ms/step - loss: 7.4535e-04
# Epoch 32/50
# 83/83 [==============================] - 24s 289ms/step - loss: 6.4861e-04
# Epoch 33/50
# 83/83 [==============================] - 24s 290ms/step - loss: 6.2660e-04
# Epoch 34/50
# 83/83 [==============================] - 24s 289ms/step - loss: 7.4140e-04
# Epoch 35/50
# 83/83 [==============================] - 24s 290ms/step - loss: 7.6306e-04
# Epoch 36/50
# 83/83 [==============================] - 24s 289ms/step - loss: 7.8371e-04
# Epoch 37/50
# 83/83 [==============================] - 24s 293ms/step - loss: 6.0274e-04
# Epoch 38/50
# 83/83 [==============================] - 26s 311ms/step - loss: 6.1862e-04
# Epoch 39/50
# 83/83 [==============================] - 24s 292ms/step - loss: 6.8552e-04
# Epoch 40/50
# 83/83 [==============================] - 24s 295ms/step - loss: 6.7273e-04
# Epoch 41/50
# 83/83 [==============================] - 25s 296ms/step - loss: 5.8921e-04
# Epoch 42/50
# 83/83 [==============================] - 25s 301ms/step - loss: 5.4258e-04
# Epoch 43/50
# 83/83 [==============================] - 25s 300ms/step - loss: 6.4590e-04
# Epoch 44/50
# 83/83 [==============================] - 24s 294ms/step - loss: 6.8423e-04
# Epoch 45/50
# 83/83 [==============================] - 24s 292ms/step - loss: 5.9118e-04
# Epoch 46/50
# 83/83 [==============================] - 24s 293ms/step - loss: 5.6108e-04
# Epoch 47/50
# 83/83 [==============================] - 25s 296ms/step - loss: 5.6300e-04
# Epoch 48/50
# 83/83 [==============================] - 25s 296ms/step - loss: 5.4528e-04
# Epoch 49/50
# 83/83 [==============================] - 24s 294ms/step - loss: 6.6873e-04
# Epoch 50/50
# 83/83 [==============================] - 19s 225ms/step - loss: 5.9111e-04

# %%
model.summary()
# Out:
# Model: "Sber"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 360, 128)          66560
#
#  dropout (Dropout)           (None, 360, 128)          0
#
#  lstm_1 (LSTM)               (None, 360, 64)           49408
#
#  dropout_1 (Dropout)         (None, 360, 64)           0
#
#  lstm_2 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 149,057
# Trainable params: 149,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
predict = model.predict(x_test)
predict = scaler.inverse_transform(predict)
y_test_scaled = scaler.inverse_transform(y_test.reshape(-1, 1))

plt.figure(figsize=(16, 8))

plt.plot(y_test_scaled, color='r', label='Original')
plt.plot(predict, color='b', label='Predicted')

plt.legend()

plt.show()
