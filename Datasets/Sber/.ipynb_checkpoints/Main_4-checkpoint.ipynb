# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('DS_Sber.csv', sep=';')
data.columns = data.columns.str.lower()
data['reportdate'] = data['reportdate'].str.replace('.', '/')
data["reportdate"] = pd.to_datetime(data["reportdate"], infer_datetime_format=True)

data.head(10)
# Out:
# C:\Temp\ipykernel_11792\4256145899.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['reportdate'] = data['reportdate'].str.replace('.', '/')
#   reportdate       value
# 0 2013-12-30  3457625638
# 1 2013-12-31  3417092149
# 2 2014-01-01  3417092149
# 3 2014-01-02  3417092149
# 4 2014-01-03  3417092149
# 5 2014-01-04  3417092149
# 6 2014-01-05  3417092149
# 7 2014-01-06  3320846785
# 8 2014-01-07  3320846785
# 9 2014-01-08  3630283744

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   reportdate  2111 non-null   datetime64[ns]
#  1   value       2111 non-null   int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 33.1 KB

# %%
data.describe()
# Out:
#               value
# count  2.111000e+03
# mean   3.389668e+10
# std    1.875474e+10
# min    3.282810e+09
# 25%    1.824160e+10
# 50%    3.021352e+10
# 75%    4.758339e+10
# max    7.822860e+10

# %%
data.boxplot(['value'])
# Out:
# <AxesSubplot: >

# %%
plt.figure(figsize=(10, 7))

plt.grid(True)
plt.plot(data.reportdate, data.value)

plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential, load_model
from keras.layers import LSTM, Dense, Dropout

# %%
df = data['value'].values.reshape((-1, 1))[252:]
df
# Out:
# array([[19175854331],
#        [19739611315],
#        [19433070371],
#        ...,
#        [68424049766],
#        [72492897583],
#        [72307860851]], dtype=int64)

# %%
dataset_train = np.array(df[:int(df.shape[0]*0.8)])
dataset_test = np.array(df[int(df.shape[0]*0.8):])

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
dataset_train = scaler.fit_transform(dataset_train)
dataset_test = scaler.transform(dataset_test)

dataset_train
# Out:
# array([[0.12949958],
#        [0.14128199],
#        [0.13487535],
#        ...,
#        [0.75412709],
#        [0.76059506],
#        [0.77529796]])

# %%
def create_dataset(df, window):
    x = []
    y = []
    for i in range(window, df.shape[0]):
        x.append(df[i-window:i, 0])
        y.append(df[i, 0])
    x = np.array(x)
    y = np.array(y)
    return (x, y)

# %%
window = 30 * 12

x_train, y_train = create_dataset(dataset_train, window)
x_test, y_test = create_dataset(dataset_test, window)

x_train, y_train
# Out:
# (array([[0.12949958, 0.14128199, 0.13487535, ..., 0.07714498, 0.07960169,
#          0.0953803 ],
#         [0.14128199, 0.13487535, 0.17264166, ..., 0.07960169, 0.0953803 ,
#          0.10633128],
#         [0.13487535, 0.17264166, 0.17384872, ..., 0.0953803 , 0.10633128,
#          0.1062059 ],
#         ...,
#         [0.63146506, 0.63146506, 0.63146506, ..., 0.74705403, 0.74705403,
#          0.74705403],
#         [0.63146506, 0.63146506, 0.59624954, ..., 0.74705403, 0.74705403,
#          0.75412709],
#         [0.63146506, 0.59624954, 0.63052316, ..., 0.74705403, 0.75412709,
#          0.76059506]]),
#  array([0.10633128, 0.1062059 , 0.1062059 , ..., 0.75412709, 0.76059506,
#         0.77529796]))

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

x_train.shape, y_train.shape
# Out:
# ((1127, 360, 1), (1127,))

# %%
def create_model():
    model = Sequential(name='Sber')
    model.add(LSTM(units=128, activation='relu', return_sequences=True, input_shape=(x_train.shape[1], 1)))
    model.add(Dropout(0.2))
    model.add(LSTM(units=128, return_sequences=True, activation='relu'))
    model.add(Dropout(0.2))
    model.add(LSTM(units=1, activation='relu'))
    model.add(Dense(units=1))
    
    model.compile(loss='mean_squared_error', optimizer='adam')
    
    return model

# %%
model = create_model()

model.summary()
# Out:
# Model: "Sber"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_3 (LSTM)               (None, 360, 128)          66560
#
#  dropout_2 (Dropout)         (None, 360, 128)          0
#
#  lstm_4 (LSTM)               (None, 360, 128)          131584
#
#  dropout_3 (Dropout)         (None, 360, 128)          0
#
#  lstm_5 (LSTM)               (None, 1)                 520
#
#  dense_1 (Dense)             (None, 1)                 2
#
# ...
# Total params: 198,666
# Trainable params: 198,666
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, batch_size=16, epochs=50)
# Out:
# Epoch 1/50
# 71/71 [==============================] - 34s 424ms/step - loss: 0.0258
# Epoch 2/50
# 71/71 [==============================] - 30s 426ms/step - loss: 0.0050
# Epoch 3/50
# 71/71 [==============================] - 31s 435ms/step - loss: 0.0044
# Epoch 4/50
# 71/71 [==============================] - 23s 325ms/step - loss: 0.0042
# Epoch 5/50
# 71/71 [==============================] - 22s 315ms/step - loss: 0.0042
# Epoch 6/50
# 71/71 [==============================] - 22s 311ms/step - loss: 0.0037
# Epoch 7/50
# 71/71 [==============================] - 25s 354ms/step - loss: 0.0032
# Epoch 8/50
# 71/71 [==============================] - 22s 309ms/step - loss: 0.0030
# Epoch 9/50
# 71/71 [==============================] - 26s 369ms/step - loss: 0.0026
# Epoch 10/50
# 71/71 [==============================] - 23s 329ms/step - loss: 0.0026
# Epoch 11/50
# 71/71 [==============================] - 22s 304ms/step - loss: 0.0024
# Epoch 12/50
# ...

# %%
predict = model.predict(x_test)
predict = scaler.inverse_transform(predict)
y_test_scaled = scaler.inverse_transform(y_test.reshape(-1, 1))

plt.figure(figsize=(16, 8))

plt.plot(y_test_scaled, color='r', label='Original')
plt.plot(predict, color='b', label='Predicted')

plt.legend()

plt.show()

# %%
dataset_valid = np.array(df)

dataset_valid = scaler.transform(dataset_valid)

dataset_valid = np.reshape(dataset_valid, (dataset_valid.shape[0], dataset_valid.shape[1], 1))

x_dataset_valid, y_dataset_valid = create_dataset(dataset_valid, window)

predict = model.predict(x_dataset_valid)
predict = scaler.inverse_transform(predict)
dataset_valid = scaler.inverse_transform(y_dataset_valid)

plt.figure(figsize=(16, 8))

plt.plot(dataset_valid, color='r', label='Original')
plt.plot(predict, color='b', label='Predicted')

plt.legend()

plt.show()

# %%
df_1 = df.copy()

for i in range(window):
    test = df_1.copy()

    test = test[-window:]

    test = scaler.transform(test.reshape(-1, 1)).reshape(-1)

    test = scaler.inverse_transform(model.predict(test.reshape(1, window, 1))).reshape(-1)

    df_1 = np.append(df_1, test)
    
df_1[-window:]
# Out:
# array([6.75311370e+10, 6.68250767e+10, 6.47431660e+10, 6.27609846e+10,
#        6.05039493e+10, 5.94096333e+10, 5.89955727e+10, 5.82547210e+10,
#        5.90314865e+10, 5.78806006e+10, 5.84639570e+10, 5.81433385e+10,
#        5.76449413e+10, 5.67891476e+10, 5.53083249e+10, 5.43002911e+10,
#        5.33032632e+10, 5.70054902e+10, 5.25331743e+10, 5.26662287e+10,
#        5.21683763e+10, 5.36473477e+10, 5.11875113e+10, 5.10127309e+10,
#        5.08289229e+10, 5.06223452e+10, 5.05107661e+10, 5.06069156e+10,
#        5.08578447e+10, 5.36427684e+10, 5.20705638e+10, 5.30595963e+10,
#        5.39366605e+10, 5.45326899e+10, 5.51799726e+10, 5.58717338e+10,
#        5.65758403e+10, 5.71996242e+10, 5.76740557e+10, 5.79904061e+10,
#        5.79635773e+10, 5.64563804e+10, 5.63439206e+10, 5.72078285e+10,
#        5.66841795e+10, 5.55492925e+10, 5.30943959e+10, 5.28569836e+10,
#        5.16374610e+10, 5.07078984e+10, 4.99218432e+10, 4.98115256e+10,
# ...

# %%
plt.plot(df_1)
plt.plot(np.append(df_1[:-window] * np.nan, df_1[-window:]))

# %%
test = df.copy()

test = test[-window:]

test = scaler.transform(test.reshape(-1, 1)).reshape(-1)

test = scaler.inverse_transform(model.predict(test.reshape(1, window, 1))).reshape(-1)

test.reshape(-1)
# Out:
# array([6.7531137e+10], dtype=float32)

# %%
plt.plot(df)

plt.plot(np.append(np.array(df)*0, test.reshape(-1)))

# %%
def create_model_1():
    model = Sequential(name='Sber')
    model.add(LSTM(units=128, activation='relu', return_sequences=True, input_shape=(x_test_1.shape[1], 1)))
    model.add(Dropout(0.2))
    model.add(LSTM(units=128, return_sequences=True, activation='relu'))
    model.add(Dropout(0.2))
    model.add(LSTM(units=1, activation='relu'))
    model.add(Dense(units=1))
    
    model.compile(loss='mean_squared_error', optimizer='adam')
    
    return model

# %%
scaler_1 = MinMaxScaler(feature_range=(0, 1))
# dataset_test_1 = scaler_1.fit_transform(np.array(df[int(df.shape[0]*0.8):]))
dataset_test_1 = scaler_1.fit_transform(np.array(df))

x_test_1, y_test_1 = create_dataset(dataset_test_1, window)

x_test_1 = np.reshape(x_test_1, (x_test_1.shape[0], x_test_1.shape[1], 1))

model_1 = create_model_1()

model_1.summary()
# Out:
# Model: "Sber"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_6 (LSTM)               (None, 360, 128)          66560
#
#  dropout_4 (Dropout)         (None, 360, 128)          0
#
#  lstm_7 (LSTM)               (None, 360, 128)          131584
#
#  dropout_5 (Dropout)         (None, 360, 128)          0
#
#  lstm_8 (LSTM)               (None, 1)                 520
#
#  dense_2 (Dense)             (None, 1)                 2
#
# ...
# Total params: 198,666
# Trainable params: 198,666
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_1.fit(x_test_1, y_test_1, batch_size=16, epochs=50)
# Out:
# Epoch 1/50
# 94/94 [==============================] - 34s 338ms/step - loss: 0.2208
# Epoch 2/50
# 94/94 [==============================] - 31s 328ms/step - loss: 0.1610
# Epoch 3/50
# 94/94 [==============================] - 30s 316ms/step - loss: 0.1208
# Epoch 4/50
# 94/94 [==============================] - 28s 295ms/step - loss: 0.0952
# Epoch 5/50
# 94/94 [==============================] - 32s 337ms/step - loss: 0.0799
# Epoch 6/50
# 94/94 [==============================] - 31s 330ms/step - loss: 0.0713
# Epoch 7/50
# 94/94 [==============================] - 30s 319ms/step - loss: 0.0670
# Epoch 8/50
# 94/94 [==============================] - 30s 324ms/step - loss: 0.0650
# Epoch 9/50
# 94/94 [==============================] - 30s 320ms/step - loss: 0.0641
# Epoch 10/50
# 94/94 [==============================] - 30s 324ms/step - loss: 0.0637
# Epoch 11/50
# 94/94 [==============================] - 30s 323ms/step - loss: 0.0636
# Epoch 12/50
# ...

# %%
plt.plot(y_test_1)
plt.plot(model_1.predict(x_test_1))

# %%
model_1.predict(x_test_1)

# %%
test_1 = scaler.transform(df.reshape(-1, 1))

test_1 = test_1[-window:]

test_1 = test_1.reshape(1, window, 1)

model_1.predict(test_1), test_1
