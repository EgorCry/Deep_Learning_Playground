# %%
import pandas as pd
import numpy as mp
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('event_data_train_online_courses.csv')

data.head()
# Out:
#    step_id   timestamp      action  user_id
# 0    32815  1434340848      viewed    17632
# 1    32815  1434340848      passed    17632
# 2    32815  1434340848  discovered    17632
# 3    32811  1434340895  discovered    17632
# 4    32811  1434340895      viewed    17632

# %%
data_s = pd.read_csv('submissions_data_train_online_courses.csv')

data_s.head()
# Out:
#    step_id   timestamp submission_status  user_id
# 0    31971  1434349275           correct    15853
# 1    31972  1434348300           correct    15853
# 2    31972  1478852149             wrong    15853
# 3    31972  1478852164           correct    15853
# 4    31976  1434348123             wrong    15853

# %%
sorted(data.user_id.value_counts())
# Out:
# [1,
#  1,
#  1,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
# ...

# %%
data[data.action == 'started_attempt'].user_id.value_counts()
# Out:
# 1046     721
# 3572     550
# 8394     337
# 6662     285
# 1649     281
#         ...
# 17936      1
# 20012      1
# 5781       1
# 8138       1
# 943        1
# Name: user_id, Length: 11400, dtype: int64

# %%
data[data.].step_id.value_counts()
# Out:
# 32927     60553
# 32815     51189
# 32950     50847
# 32812     48570
# 32929     46478
#           ...
# 33914      6530
# 34051      6314
# 34049      6307
# 34052      6159
# 109765     4152
# Name: step_id, Length: 198, dtype: int64

# %%
data.action.unique()
# Out:
# array(['viewed', 'passed', 'discovered', 'started_attempt'], dtype=object)

# %%
data_s[data_s.submission_status == 'correct'].user_id.value_counts()
# Out:
# 1046     421
# 5552     186
# 17135    168
# 6183     142
# 8461     135
#         ...
# 17260      1
# 22761      1
# 26061      1
# 6683       1
# 13177      1
# Name: user_id, Length: 9794, dtype: int64

# %% [markdown]
# Tolya is 1046
